# %%
import matplotlib.pyplot as plt 
import numpy as np

# %% [markdown]
# ## inteprolation visualization

# %% [markdown]
# ### NOAA

# %%
true_data = np.load("../data/processed/NOAA/NOAA_float64_1_mean.npy")
interpolation = np.load("../data/processed/NOAA/interpolation_voronoi_float64_1_mean_vib_0_noise_0.0_[0, 20, 40, 60, 80, 100, 120, 140, 160]_[0, 20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340].npy")

# %%
plt.imshow(true_data[100])

# %%
plt.imshow(interpolation[100])

# %% [markdown]
# ### IAEA

# %%
true_data = np.load("../data/processed/IAEA/phitwo_float16_2_mean.npy")
interpolation = np.load("../data/processed/IAEA/interpolation_voronoi_float16_2_mean_vib_0_noise_0.0_[0, 10, 20, 30, 40, 50, 60, 70, 80, 85]_[0, 10, 20, 30, 40, 50, 60, 70, 80, 85].npy")

# %%
plt.imshow(true_data[100])

# %%
plt.imshow(interpolation[100])
